# %% [markdown]
# # SYSID - Trabalho (ML - MISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

#Interface SYSID
from SYSIDPreProcessor import SYSIDRegressor

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# c:\Users\bewm\Documents\Projetos\Mestrado\SYSID_Trabalho\Volve-Dataset\data\volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        'AVG_DOWNHOLE_PRESSURE',
        'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        'AVG_WHT_P',
        'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 5) (718, 5)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X_tr = X_scale.fit_transform(X1_tr)
X_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=1)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)

models.append(('ARMAX', model))

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %%
basis_function = Fourier(degree=2)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)
models.append(('NARMAX', model))

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    #{
    #    'activation'            : ['relu', 'logistic', 'tanh'],
    #    'early_stopping'        : [True, False],
    #    'alpha'                 : stats.loguniform(1e-9, 1e0),
    #    'hidden_layer_sizes'    : [(100,), (100, 100,), (100, 100, 100,), (100, 100, 100, 100,)],
    #    'max_iter'              : [10000],#stats.randint(200,10000),
    #    'batch_size'            : [32, 64, 128, 256, 'auto'],
    #    'solver'                : ['adam'], #'lbfgs'],
    #    'tol'                   : stats.loguniform(1e-7, 1e-1),
    #},
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    sidmodel = SYSIDRegressor(
        nX=6, ny=6,
        estimator=rdmsearch, 
        preprocessor=MinMaxScaler(),
        #expansor=PolynomialFeatures(degree=2)
        )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
models[-1]
# Out:
# ('MLP',
#  SYSIDRegressor(estimator=RandomizedSearchCV(cv=RepeatedKFold(n_repeats=10, n_splits=5, random_state=71),
#                                              estimator=MLPRegressor(random_state=85),
#                                              n_iter=100, n_jobs=6,
#                                              param_distributions={'activation': ['relu'],
#                                                                   'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177EBCFF100>,
#                                                                   'batch_size': [16,
#                                                                                  32,
#                                                                                  64,
#                                                                                  128,
#                                                                                  256],
#                                                                   'early_stopping': [True...
#                                                                                          (40,
#                                                                                           60),
#                                                                                          (40,
#                                                                                           80),
#                                                                                          (40,
#                                                                                           100),
#                                                                                          (60,
#                                                                                           20),
#                                                                                          (60,
#                                                                                           40),
#                                                                                          (60,
#                                                                                           60),
#                                                                                          (60,
#                                                                                           80),
#                                                                                          (60,
#                                                                                           100),
#                                                                                          (80,
#                                                                                           20),
#                                                                                          (80,
#                                                                                           40),
#                                                                                          (80,
#                                                                                           60),
#                                                                                          (80,
#                                                                                           80),
#                                                                                          (80,
#                                                                                           100),
#                                                                                          (100,
#                                                                                           20),
#                                                                                          (100,
#                                                                                           40),
#                                                                                          (100,
#                                                                                           60),
#                                                                                          (100,
#                                                                                           80),
#                                                                                          (100,
#                                                                                           100), ...],
#                                                                   'max_iter': [10000],
#                                                                   'solver': ['adam'],
#                                                                   'tol': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177EBD088B0>},
#                                              random_state=85, scoring='r2'),
#                 nX=6, ny=6, preprocessor=MinMaxScaler()))

# %%
n_models = len(models)

results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

# %%
for model in models:
    print(model[0])
# Out:
# ARMAX
# NARMAX
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'MISO.W1'
#Loop principal, iterando sobre as listas
for model in models:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1))
        r2_te_osa = r2_score(y_te, sidmodel.predict(X1_te, y=y_te, steps_ahead=1))
        try:
            r2_tr_fs = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr))
            r2_te_fs = r2_score(y_te, sidmodel.predict(X1_te, y=y_te))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = sidmodel
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(sidmodel)
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    
    if hasattr(sidmodel, 'nX'): # is from our package
        best_model.nX = best_order
        best_model.ny = best_order
    else:
        best_model.xlag = [best_order]*X1_tr.shape[1]
        best_model.ylag = best_order
        best_model.elag = best_order
    with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            best_model.fit(X=X1_tr, y=y_tr)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr, label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:], label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:], label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs',f'{prefix}_{model_name}.png'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(sidmodel)
    try:
        results['PARS'].append(sidmodel.estimator.best_params_)
    except Exception:
        results['PARS'].append(sidmodel.final_model)
# Out:
# Starting evaluation of model: ARMAX
#     Trying order: 2
#         R2 score OSA (Train): 0.7641625156028278
#         R2 score OSA (Test): 0.758294097323772
#         R2 score FS (Train): -202.3348142026926
#         R2 score FS (Test): -195.36021387762764
#     Trying order: 3
#         R2 score OSA (Train): 0.7437914179340153
#         R2 score OSA (Test): 0.7481598617142595
#         R2 score FS (Train): -745.3034947184733
#         R2 score FS (Test): -696.1635737652865
#     Trying order: 4
#         R2 score OSA (Train): 0.7472017138390781
#         R2 score OSA (Test): 0.7567690218786842
#         R2 score FS (Train): -532.5541428149168
#         R2 score FS (Test): -494.9729251050587
#     Trying order: 5
#         R2 score OSA (Train): 0.7364575903637471
#         R2 score OSA (Test): 0.7544926921600972
#         R2 score FS (Train): -2738.5243329239747
#         R2 score FS (Test): -2709.145317669569
#     Trying order: 6
#         R2 score OSA (Train): 0.7602377623108474
#         R2 score OSA (Test): 0.7687032587854172
#         R2 score FS (Train): -19.40641258487884
#         R2 score FS (Test): -20.04043211554116
#     Trying order: 7
#         R2 score OSA (Train): 0.7328468316474948
#         R2 score OSA (Test): 0.7484797547475969
#         R2 score FS (Train): -2172.9424667353287
#         R2 score FS (Test): -2146.025787723288
#     Trying order: 8
#         R2 score OSA (Train): 0.7195621710351163
#         R2 score OSA (Test): 0.7424211394763681
#         R2 score FS (Train): -1387.7240427758852
#         R2 score FS (Test): -1375.867004448008
#     Trying order: 9
#         R2 score OSA (Train): 0.7343057948308824
#         R2 score OSA (Test): 0.7526476294848232
#         R2 score FS (Train): -10.078344502643827
#         R2 score FS (Test): -9.314900743124788
#     Trying order: 10
#         R2 score OSA (Train): 0.7271893604549529
#         R2 score OSA (Test): 0.7499392060355992
#         R2 score FS (Train): -21.464208849212206
#         R2 score FS (Test): -19.987750035814408
#     Trying order: 11
#         R2 score OSA (Train): 0.758956707860136
#         R2 score OSA (Test): 0.7603792356058241
#         R2 score FS (Train): -0.08882149336778955
#         R2 score FS (Test): -0.08781171332509508
#     Trying order: 12
#         R2 score OSA (Train): 0.7746754742514341
#         R2 score OSA (Test): 0.7761066042508021
#         R2 score FS (Train): -2.655041581138686
#         R2 score FS (Test): -2.3747812236037364
#     Trying order: 13
#         R2 score OSA (Train): 0.6282899409194043
#         R2 score OSA (Test): 0.68757582205319
#         R2 score FS (Train): -2.3290723394118475
#         R2 score FS (Test): -2.4031185451971524
#     Trying order: 14
#         R2 score OSA (Train): 0.602963516372515
#         R2 score OSA (Test): 0.667736334284581
#         R2 score FS (Train): -2552.0186255322724
#         R2 score FS (Test): -2506.237588771494
#     Trying order: 15
#         R2 score OSA (Train): 0.6489421561100603
#         R2 score OSA (Test): 0.700662489521527
#         R2 score FS (Train): -1.4624855585820056
#         R2 score FS (Test): -1.4000003853042107
#     Trying order: 16
#         R2 score OSA (Train): 0.6162421790830129
#         R2 score OSA (Test): 0.6803899201328318
#         R2 score FS (Train): -1.6732216253395222
#         R2 score FS (Test): -1.588649790647422
#     Trying order: 17
#         R2 score OSA (Train): 0.6221749408680202
#         R2 score OSA (Test): 0.6813959566595926
#         R2 score FS (Train): -1.9833905340878237
#         R2 score FS (Test): -2.204476982452007
#     Trying order: 18
#         R2 score OSA (Train): 0.6228254039794775
#         R2 score OSA (Test): 0.6799739031071559
#         R2 score FS (Train): -5.222711815443664
#         R2 score FS (Test): -5.833288017238653
#     Trying order: 19
#         R2 score OSA (Train): 0.6319130678071985
#         R2 score OSA (Test): 0.6860176740823904
#         R2 score FS (Train): -37.95758396791781
#         R2 score FS (Test): -35.763390530588396
#     Trying order: 20
#         R2 score OSA (Train): 0.6304683975046864
#         R2 score OSA (Test): 0.6811557415243461
#         R2 score FS (Train): -1.6169335980691133
#         R2 score FS (Test): -1.7044378257592485
#
#     Tempo de execução: 0:00:06.956782
#     Best Order: 11
#     R2 score OSA (Train): 0.758956707860136
#     R2 score OSA (Test): 0.7603792356058241
#     R2 score FS (Train): -0.08882149336778955
#     R2 score FS (Test): -0.08781171332509508
#
# Starting evaluation of model: NARMAX
#     Trying order: 2
#         R2 score OSA (Train): 0.7808245737305302
#         R2 score OSA (Test): 0.772463663792178
#         R2 score FS (Train): 0.6162167713514751
#         R2 score FS (Test): 0.601519270334687
#     Trying order: 3
#         R2 score OSA (Train): 0.7782026826725462
#         R2 score OSA (Test): 0.775073140955354
#         R2 score FS (Train): -0.06956768253346324
#         R2 score FS (Test): -0.1262429996993759
#     Trying order: 4
#         R2 score OSA (Train): 0.7478109509270898
#         R2 score OSA (Test): 0.7428212721025464
#         R2 score FS (Train): -2.4611593756110444
#         R2 score FS (Test): -2.6031625691192546
#     Trying order: 5
#         R2 score OSA (Train): 0.6328051455657793
#         R2 score OSA (Test): 0.6697058443017607
#         R2 score FS (Train): -1.8901106940855708
#         R2 score FS (Test): -1.9165770205171997
#     Trying order: 6
#         R2 score OSA (Train): 0.7822669919492387
#         R2 score OSA (Test): 0.7807986172599126
#         R2 score FS (Train): -0.35840585393030566
#         R2 score FS (Test): -0.41354274418576664
#     Trying order: 7
#         R2 score OSA (Train): 0.7784523198188171
#         R2 score OSA (Test): 0.7665086036629263
#         R2 score FS (Train): -1.0925256013611953
#         R2 score FS (Test): -1.252094721068413
#     Trying order: 8
#         R2 score OSA (Train): 0.7762922286636397
#         R2 score OSA (Test): 0.7645981357694756
#         R2 score FS (Train): -1.0675117883346998
#         R2 score FS (Test): -1.218385087515029
#     Trying order: 9
#         R2 score OSA (Train): 0.7813475855267499
#         R2 score OSA (Test): 0.768728865944739
#         R2 score FS (Train): -1.6003995322921925
#         R2 score FS (Test): -1.6790812711175485
#     Trying order: 10
#         R2 score OSA (Train): 0.7842496620626348
#         R2 score OSA (Test): 0.7731940253658195
#         R2 score FS (Train): -0.8097745055738106
#         R2 score FS (Test): -0.9238510315244757
#     Trying order: 11
#         R2 score OSA (Train): 0.7754685028234538
#         R2 score OSA (Test): 0.7681752358861812
#         R2 score FS (Train): -2.08242127097462
#         R2 score FS (Test): -1.547458187816181
#     Trying order: 12
#         R2 score OSA (Train): 0.7779528243153542
#         R2 score OSA (Test): 0.7665643634691055
#         R2 score FS (Train): -0.40135358545394495
#         R2 score FS (Test): -0.40356124317774267
#     Trying order: 13
#         R2 score OSA (Train): 0.7815238470501596
#         R2 score OSA (Test): 0.7839529412089932
#         R2 score FS (Train): -0.3378695668590459
#         R2 score FS (Test): -0.3378193692509357
#     Trying order: 14
#         R2 score OSA (Train): 0.7957367001173686
#         R2 score OSA (Test): 0.7928078679468413
#         R2 score FS (Train): -0.18424852983395512
#         R2 score FS (Test): -0.1922953867063184
#     Trying order: 15
#         R2 score OSA (Train): 0.7769390980064261
#         R2 score OSA (Test): 0.7822762825912053
#         R2 score FS (Train): -1.7180794982312966
#         R2 score FS (Test): -1.9694759539598232
#     Trying order: 16
#         R2 score OSA (Train): 0.7647001358158452
#         R2 score OSA (Test): 0.7603791950233245
#         R2 score FS (Train): -1.8065720146578563
#         R2 score FS (Test): -1.421479184080761
#     Trying order: 17
#         R2 score OSA (Train): 0.7675295172551024
#         R2 score OSA (Test): 0.7702206238677473
#         R2 score FS (Train): -0.8301512373881084
#         R2 score FS (Test): -1.2254745964900047
#     Trying order: 18
#         R2 score OSA (Train): 0.7659061480184294
#         R2 score OSA (Test): 0.763140792719399
#         R2 score FS (Train): -1.571957954387425
#         R2 score FS (Test): -1.860607657356553
#     Trying order: 19
#         R2 score OSA (Train): 0.7825727042993029
#         R2 score OSA (Test): 0.7760098228528207
#         R2 score FS (Train): -0.5138252946458977
#         R2 score FS (Test): -0.556531127176922
#     Trying order: 20
#         R2 score OSA (Train): 0.7763650650081811
#         R2 score OSA (Test): 0.7795003840417819
#         R2 score FS (Train): -2.276675169978209
#         R2 score FS (Test): -2.8809806032001175
#
#     Tempo de execução: 0:38:16.936818
#     Best Order: 2
#     R2 score OSA (Train): 0.7808245737305302
#     R2 score OSA (Test): 0.772463663792178
#     R2 score FS (Train): 0.6162167713514751
#     R2 score FS (Test): 0.601519270334687
#
# Starting evaluation of model: LinReg
#     Trying order: 2
#         R2 score OSA (Train): 0.7958934015171792
#         R2 score OSA (Test): 0.7869273326730327
#         R2 score FS (Train): 0.5823485550442125
#         R2 score FS (Test): 0.5883095416383566
#     Trying order: 3
#         R2 score OSA (Train): 0.8037729920416319
#         R2 score OSA (Test): 0.7949811504252052
#         R2 score FS (Train): 0.584051372315443
#         R2 score FS (Test): 0.5918862443635596
#     Trying order: 4
#         R2 score OSA (Train): 0.8038363864501297
#         R2 score OSA (Test): 0.7950571947656742
#         R2 score FS (Train): 0.584551230745023
#         R2 score FS (Test): 0.5923951857539069
#     Trying order: 5
#         R2 score OSA (Train): 0.8084205883171423
#         R2 score OSA (Test): 0.798466504458603
#         R2 score FS (Train): 0.5813887612347775
#         R2 score FS (Test): 0.5890813787841819
#     Trying order: 6
#         R2 score OSA (Train): 0.8119736106533451
#         R2 score OSA (Test): 0.8012065986924479
#         R2 score FS (Train): 0.5844596910234147
#         R2 score FS (Test): 0.588739726638082
#     Trying order: 7
#         R2 score OSA (Train): 0.814877442274812
#         R2 score OSA (Test): 0.8017616623334394
#         R2 score FS (Train): 0.5792581450369378
#         R2 score FS (Test): 0.582548395712676
#     Trying order: 8
#         R2 score OSA (Train): 0.814963337308735
#         R2 score OSA (Test): 0.8018007569585983
#         R2 score FS (Train): 0.5783759993567904
#         R2 score FS (Test): 0.580534558709662
#     Trying order: 9
#         R2 score OSA (Train): 0.8154418816784558
#         R2 score OSA (Test): 0.801965906985742
#         R2 score FS (Train): 0.5762507564546067
#         R2 score FS (Test): 0.5764557143682087
#     Trying order: 10
#         R2 score OSA (Train): 0.8155979520017019
#         R2 score OSA (Test): 0.8021074902252047
#         R2 score FS (Train): 0.5779737884407188
#         R2 score FS (Test): 0.5784159547260541
#     Trying order: 11
#         R2 score OSA (Train): 0.8156821890833047
#         R2 score OSA (Test): 0.8022572360101052
#         R2 score FS (Train): 0.5795815738728518
#         R2 score FS (Test): 0.5803333271959695
#     Trying order: 12
#         R2 score OSA (Train): 0.8165510263614948
#         R2 score OSA (Test): 0.8017440924405799
#         R2 score FS (Train): 0.5785957605055101
#         R2 score FS (Test): 0.5770695261335723
#     Trying order: 13
#         R2 score OSA (Train): 0.817277996603553
#         R2 score OSA (Test): 0.8019561396583734
#         R2 score FS (Train): 0.5787489772911032
#         R2 score FS (Test): 0.5775678337314382
#     Trying order: 14
#         R2 score OSA (Train): 0.8177983255286707
#         R2 score OSA (Test): 0.8020095119748198
#         R2 score FS (Train): 0.5763660813347429
#         R2 score FS (Test): 0.5759887415890244
#     Trying order: 15
#         R2 score OSA (Train): 0.8181036807090369
#         R2 score OSA (Test): 0.8012689093246849
#         R2 score FS (Train): 0.5691494136347937
#         R2 score FS (Test): 0.5671428512800049
#     Trying order: 16
#         R2 score OSA (Train): 0.8181061219277261
#         R2 score OSA (Test): 0.8012824286479132
#         R2 score FS (Train): 0.5691916296904431
#         R2 score FS (Test): 0.5672484277634202
#     Trying order: 17
#         R2 score OSA (Train): 0.8181062947599355
#         R2 score OSA (Test): 0.8012864168575333
#         R2 score FS (Train): 0.5691679651073742
#         R2 score FS (Test): 0.5672367091889406
#     Trying order: 18
#         R2 score OSA (Train): 0.818109758663779
#         R2 score OSA (Test): 0.8012950617743166
#         R2 score FS (Train): 0.5692776707143281
#         R2 score FS (Test): 0.5673656936223982
#     Trying order: 19
#         R2 score OSA (Train): 0.818277660458516
#         R2 score OSA (Test): 0.8013587762085777
#         R2 score FS (Train): 0.5702242042313901
#         R2 score FS (Test): 0.5681712599689333
#     Trying order: 20
#         R2 score OSA (Train): 0.8196632417976102
#         R2 score OSA (Test): 0.8017121861429972
#         R2 score FS (Train): 0.5702800500853089
#         R2 score FS (Test): 0.5657576836653245
#
#     Tempo de execução: 0:00:11.213931
#     Best Order: 4
#     R2 score OSA (Train): 0.8038363864501297
#     R2 score OSA (Test): 0.7950571947656742
#     R2 score FS (Train): 0.584551230745023
#     R2 score FS (Test): 0.5923951857539069
#
# Starting evaluation of model: PolyReg
#     Trying order: 2
#         R2 score OSA (Train): 0.8082016191575888
#         R2 score OSA (Test): 0.800343999312416
#         R2 score FS (Train): 0.6444323802336672
#         R2 score FS (Test): 0.6534636059901788
#     Trying order: 3
#         R2 score OSA (Train): 0.8158370791074457
#         R2 score OSA (Test): 0.8044782415028346
#         R2 score FS (Train): 0.6496184894264952
#         R2 score FS (Test): 0.6595886475402283
#     Trying order: 4
#         R2 score OSA (Train): 0.8158387706706909
#         R2 score OSA (Test): 0.8044531486644868
#         R2 score FS (Train): 0.650273538322777
#         R2 score FS (Test): 0.6600057026248569
#     Trying order: 5
#         R2 score OSA (Train): 0.8212016177624728
#         R2 score OSA (Test): 0.8100797323144329
#         R2 score FS (Train): 0.6551084393161601
#         R2 score FS (Test): 0.6627231629235691
#     Trying order: 6
#         R2 score OSA (Train): 0.8251524372460922
#         R2 score OSA (Test): 0.8127207043335447
#         R2 score FS (Train): 0.6539262824949607
#         R2 score FS (Test): 0.6604493855936598
#     Trying order: 7
#         R2 score OSA (Train): 0.8296724193870265
#         R2 score OSA (Test): 0.8150145245451441
#         R2 score FS (Train): 0.6432617291407734
#         R2 score FS (Test): 0.646250119935208
#     Trying order: 8
#         R2 score OSA (Train): 0.8304609606446919
#         R2 score OSA (Test): 0.8156511149379757
#         R2 score FS (Train): 0.6415530691766291
#         R2 score FS (Test): 0.6435000417345463
#     Trying order: 9
#         R2 score OSA (Train): 0.8316001392952179
#         R2 score OSA (Test): 0.8160336340193216
#         R2 score FS (Train): 0.6388669373284985
#         R2 score FS (Test): 0.6409470614344964
#     Trying order: 10
#         R2 score OSA (Train): 0.8318402275521892
#         R2 score OSA (Test): 0.8159208055887657
#         R2 score FS (Train): 0.6383484137852602
#         R2 score FS (Test): 0.6406322545587658
#     Trying order: 11
#         R2 score OSA (Train): 0.8332323303350317
#         R2 score OSA (Test): 0.8155315121509046
#         R2 score FS (Train): 0.6316193996959474
#         R2 score FS (Test): 0.6333806929426559
#     Trying order: 12
#         R2 score OSA (Train): 0.8340308883470785
#         R2 score OSA (Test): 0.8145907067479892
#         R2 score FS (Train): 0.6264518218364763
#         R2 score FS (Test): 0.6252300350415401
#     Trying order: 13
#         R2 score OSA (Train): 0.835750414247128
#         R2 score OSA (Test): 0.8156536323933361
#         R2 score FS (Train): 0.6259528973949421
#         R2 score FS (Test): 0.6245643700048603
#     Trying order: 14
#         R2 score OSA (Train): 0.8361060030474838
#         R2 score OSA (Test): 0.8153334683644224
#         R2 score FS (Train): 0.6209209011811171
#         R2 score FS (Test): 0.619190520020992
#     Trying order: 15
#         R2 score OSA (Train): 0.8369365821728635
#         R2 score OSA (Test): 0.8136449181991358
#         R2 score FS (Train): 0.597265766640677
#         R2 score FS (Test): 0.5819421246379888
#     Trying order: 16
#         R2 score OSA (Train): 0.8369568454573333
#         R2 score OSA (Test): 0.8135762085015108
#         R2 score FS (Train): 0.5973412925714336
#         R2 score FS (Test): 0.581776237824972
#     Trying order: 17
#         R2 score OSA (Train): 0.836996546257461
#         R2 score OSA (Test): 0.8136368661079081
#         R2 score FS (Train): 0.5968383293360588
#         R2 score FS (Test): 0.5817064725177624
#     Trying order: 18
#         R2 score OSA (Train): 0.837006757178285
#         R2 score OSA (Test): 0.8136678858457989
#         R2 score FS (Train): 0.5968373118431491
#         R2 score FS (Test): 0.5818955793119758
#     Trying order: 19
#         R2 score OSA (Train): 0.8375465900427835
#         R2 score OSA (Test): 0.812778100246736
#         R2 score FS (Train): 0.5881846620271297
#         R2 score FS (Test): 0.5584787754707958
#     Trying order: 20
#         R2 score OSA (Train): 0.8397519639272008
#         R2 score OSA (Test): 0.812134118580874
#         R2 score FS (Train): 0.5691881254660391
#         R2 score FS (Test): 0.523126764134335
#
#     Tempo de execução: 0:02:52.836096
#     Best Order: 5
#     R2 score OSA (Train): 0.8212016177624728
#     R2 score OSA (Test): 0.8100797323144329
#     R2 score FS (Train): 0.6551084393161601
#     R2 score FS (Test): 0.6627231629235691
#
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.7888248977102049
#         R2 score OSA (Test): 0.775622723074858
#         R2 score FS (Train): 0.5780241584480972
#         R2 score FS (Test): 0.5678321540694349
#     Trying order: 3
#         R2 score OSA (Train): 0.800485341387975
#         R2 score OSA (Test): 0.7866222230994264
#         R2 score FS (Train): 0.5741285628514996
#         R2 score FS (Test): 0.5653297202744507
#     Trying order: 4
#         R2 score OSA (Train): 0.8027067807497403
#         R2 score OSA (Test): 0.7870821437391817
#         R2 score FS (Train): 0.5897958216859891
#         R2 score FS (Test): 0.5798314989137598
#     Trying order: 5
#         R2 score OSA (Train): 0.8048795467943972
#         R2 score OSA (Test): 0.7892367042188447
#         R2 score FS (Train): 0.5731598019112019
#         R2 score FS (Test): 0.5639533245070334
#     Trying order: 6
#         R2 score OSA (Train): 0.8097323696001577
#         R2 score OSA (Test): 0.7936772429343124
#         R2 score FS (Train): 0.5977571102023167
#         R2 score FS (Test): 0.5843949001899235
#     Trying order: 7
#         R2 score OSA (Train): 0.8075665767081415
#         R2 score OSA (Test): 0.7911457307368945
#         R2 score FS (Train): 0.5949177371115175
#         R2 score FS (Test): 0.5857968044737656
#     Trying order: 8
#         R2 score OSA (Train): 0.8082759728059717
#         R2 score OSA (Test): 0.7920578029334544
#         R2 score FS (Train): 0.5967611260013379
#         R2 score FS (Test): 0.592500140910201
#     Trying order: 9
#         R2 score OSA (Train): 0.8101628751263539
#         R2 score OSA (Test): 0.7936051085911064
#         R2 score FS (Train): 0.5964594082571708
#         R2 score FS (Test): 0.5948447739166169
#     Trying order: 10
#         R2 score OSA (Train): 0.8135556234334369
#         R2 score OSA (Test): 0.797780396581803
#         R2 score FS (Train): 0.6063563275903434
#         R2 score FS (Test): 0.6116475797845877
#     Trying order: 11
#         R2 score OSA (Train): 0.820955757328133
#         R2 score OSA (Test): 0.8039137097553681
#         R2 score FS (Train): 0.6230192473943109
#         R2 score FS (Test): 0.6313207325694705
#     Trying order: 12
#         R2 score OSA (Train): 0.8164987952145738
#         R2 score OSA (Test): 0.7990011816160247
#         R2 score FS (Train): 0.623149409559123
#         R2 score FS (Test): 0.6341355625131246
#     Trying order: 13
#         R2 score OSA (Train): 0.8198073117455625
#         R2 score OSA (Test): 0.7988746686449635
#         R2 score FS (Train): 0.6163076449930731
#         R2 score FS (Test): 0.6308473208617397
#     Trying order: 14
#         R2 score OSA (Train): 0.8250056090179589
#         R2 score OSA (Test): 0.8016838380145603
#         R2 score FS (Train): 0.6218406102548262
#         R2 score FS (Test): 0.6394060878030079
#     Trying order: 15
#         R2 score OSA (Train): 0.825006858755442
#         R2 score OSA (Test): 0.8010002812715323
#         R2 score FS (Train): 0.600050598668934
#         R2 score FS (Test): 0.6113701808135272
#     Trying order: 16
#         R2 score OSA (Train): 0.8289873017107069
#         R2 score OSA (Test): 0.8029038844061527
#         R2 score FS (Train): 0.5957278194453324
#         R2 score FS (Test): 0.6032062334292325
#     Trying order: 17
#         R2 score OSA (Train): 0.8310600051570971
#         R2 score OSA (Test): 0.8027128484517988
#         R2 score FS (Train): 0.5936418775824744
#         R2 score FS (Test): 0.6009557272521732
#     Trying order: 18
#         R2 score OSA (Train): 0.8361569551536572
#         R2 score OSA (Test): 0.8036789767107367
#         R2 score FS (Train): 0.6106014031453896
#         R2 score FS (Test): 0.615129493851913
#     Trying order: 19
#         R2 score OSA (Train): 0.8382463823192485
#         R2 score OSA (Test): 0.8051895178475741
#         R2 score FS (Train): 0.6158846677103493
#         R2 score FS (Test): 0.6200227488308969
#     Trying order: 20
#         R2 score OSA (Train): 0.8402214590958459
#         R2 score OSA (Test): 0.8057479177275217
#         R2 score FS (Train): 0.612899740767137
#         R2 score FS (Test): 0.6118598514285538
#
#     Tempo de execução: 1:06:00.130348
#     Best Order: 12
#     R2 score OSA (Train): 0.8164987952145738
#     R2 score OSA (Test): 0.7990011816160247
#     R2 score FS (Train): 0.623149409559123
#     R2 score FS (Test): 0.6341355625131246
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 1.0
#         R2 score OSA (Test): 0.913258286725936
#         R2 score FS (Train): 0.66198640280058
#         R2 score FS (Test): 0.6061336816450349
#     Trying order: 3
#         R2 score OSA (Train): 0.9999999999996738
#         R2 score OSA (Test): 0.903301860924578
#         R2 score FS (Train): 0.6477947978215959
#         R2 score FS (Test): 0.588800437370327
#     Trying order: 4
#         R2 score OSA (Train): 0.9999999999999444
#         R2 score OSA (Test): 0.8932525350013244
#         R2 score FS (Train): 0.658303843186496
#         R2 score FS (Test): 0.6076412464027415
#     Trying order: 5
#         R2 score OSA (Train): 0.999999999999623
#         R2 score OSA (Test): 0.8996524353602209
#         R2 score FS (Train): 0.649513171220391
#         R2 score FS (Test): 0.592848086927314
#     Trying order: 6
#         R2 score OSA (Train): 0.9999999999995177
#         R2 score OSA (Test): 0.8976729467569485
#         R2 score FS (Train): 0.6486333935955302
#         R2 score FS (Test): 0.5855475407685135
#     Trying order: 7
#         R2 score OSA (Train): 0.9999999999997718
#         R2 score OSA (Test): 0.8996043934302693
#         R2 score FS (Train): 0.6546964923337509
#         R2 score FS (Test): 0.6067278947019858
#     Trying order: 8
#         R2 score OSA (Train): 0.9999999999998735
#         R2 score OSA (Test): 0.8963286971302422
#         R2 score FS (Train): 0.6708631117588588
#         R2 score FS (Test): 0.6109859618396938
#     Trying order: 9
#         R2 score OSA (Train): 0.9999999999999486
#         R2 score OSA (Test): 0.8907418751131212
#         R2 score FS (Train): 0.6679349357399218
#         R2 score FS (Test): 0.637679151238514
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999999437
#         R2 score OSA (Test): 0.891496589278299
#         R2 score FS (Train): 0.6612297265217038
#         R2 score FS (Test): 0.6405876573466148
#     Trying order: 11
#         R2 score OSA (Train): 0.9999999999999039
#         R2 score OSA (Test): 0.8963946693260677
#         R2 score FS (Train): 0.6648397403309827
#         R2 score FS (Test): 0.6349586886464685
#     Trying order: 12
#         R2 score OSA (Train): 0.9999999999999397
#         R2 score OSA (Test): 0.8990233864251971
#         R2 score FS (Train): 0.6668712340373264
#         R2 score FS (Test): 0.6317167980990693
#     Trying order: 13
#         R2 score OSA (Train): 0.999999999999928
#         R2 score OSA (Test): 0.8959206694484012
#         R2 score FS (Train): 0.6778462261128257
#         R2 score FS (Test): 0.6469081903172587
#     Trying order: 14
#         R2 score OSA (Train): 0.999999999999944
#         R2 score OSA (Test): 0.8968368313085119
#         R2 score FS (Train): 0.6943803910681743
#         R2 score FS (Test): 0.6515877877404239
#     Trying order: 15
#         R2 score OSA (Train): 0.9999999999999502
#         R2 score OSA (Test): 0.8939039125320167
#         R2 score FS (Train): 0.6890404634941489
#         R2 score FS (Test): 0.6496985516694862
#     Trying order: 16
#         R2 score OSA (Train): 0.9999999999999554
#         R2 score OSA (Test): 0.8951343993217049
#         R2 score FS (Train): 0.6999542368854272
#         R2 score FS (Test): 0.6522591280572834
#     Trying order: 17
#         R2 score OSA (Train): 0.999999999999934
#         R2 score OSA (Test): 0.9043005066023182
#         R2 score FS (Train): 0.7042679060169115
#         R2 score FS (Test): 0.6564573879027757
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999576
#         R2 score OSA (Test): 0.8927569665890374
#         R2 score FS (Train): 0.7016182097724357
#         R2 score FS (Test): 0.6672540712296041
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999452
#         R2 score OSA (Test): 0.8883332224290676
#         R2 score FS (Train): 0.7130451920060475
#         R2 score FS (Test): 0.6746695707378416
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999677
#         R2 score OSA (Test): 0.8925576744676947
#         R2 score FS (Train): 0.7217866830782971
#         R2 score FS (Test): 0.6758353675609978
#
#     Tempo de execução: 0:01:38.484905
#     Best Order: 20
#     R2 score OSA (Train): 0.9999999999999677
#     R2 score OSA (Test): 0.8925576744676947
#     R2 score FS (Train): 0.7217866830782971
#     R2 score FS (Test): 0.6758353675609978
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.8674463982941911
#         R2 score OSA (Test): 0.7991480297139268
#         R2 score FS (Train): -0.32665731284080857
#         R2 score FS (Test): -0.5377126828602745
#     Trying order: 3
#         R2 score OSA (Train): 0.8668061277837322
#         R2 score OSA (Test): 0.8185997547669231
#         R2 score FS (Train): 0.2034836153342664
#         R2 score FS (Test): 0.11380687838352554
#     Trying order: 4
#         R2 score OSA (Train): 0.837567498951052
#         R2 score OSA (Test): 0.8015435916908683
#         R2 score FS (Train): 0.012651267229272789
#         R2 score FS (Test): -0.07193889796319852
#     Trying order: 5
#         R2 score OSA (Train): 0.8136949615405666
#         R2 score OSA (Test): 0.7882557824679164
#         R2 score FS (Train): 0.5983892926850345
#         R2 score FS (Test): 0.6198021822067605
#     Trying order: 6
#         R2 score OSA (Train): 0.8089450768866738
#         R2 score OSA (Test): 0.7681352506730846
#         R2 score FS (Train): 0.5579520264380944
#         R2 score FS (Test): 0.5782305020808416
#     Trying order: 7
#         R2 score OSA (Train): 0.8309405185012713
#         R2 score OSA (Test): 0.8033177103096943
#         R2 score FS (Train): 0.6001023805970963
#         R2 score FS (Test): 0.5943518652645228
#     Trying order: 8
#         R2 score OSA (Train): 0.8374503287442119
#         R2 score OSA (Test): 0.7995654942865276
#         R2 score FS (Train): 0.27879711169629684
#         R2 score FS (Test): 0.3935631765964599
#     Trying order: 9
#         R2 score OSA (Train): 0.8592253047082912
#         R2 score OSA (Test): 0.8244721301429963
#         R2 score FS (Train): 0.6058052431148172
#         R2 score FS (Test): 0.5460865166391756
#     Trying order: 10
#         R2 score OSA (Train): 0.8183361696513338
#         R2 score OSA (Test): 0.7630375482895704
#         R2 score FS (Train): 0.6283795770256327
#         R2 score FS (Test): 0.6343059546817178
#     Trying order: 11
#         R2 score OSA (Train): 0.850113214647453
#         R2 score OSA (Test): 0.8165217584004107
#         R2 score FS (Train): 0.6224852259428759
#         R2 score FS (Test): 0.6047506618357801
#     Trying order: 12
#         R2 score OSA (Train): 0.8620875933639254
#         R2 score OSA (Test): 0.8072385579130549
#         R2 score FS (Train): 0.5983057379408356
#         R2 score FS (Test): 0.5910455979422067
#     Trying order: 13
#         R2 score OSA (Train): 0.8263036043564139
#         R2 score OSA (Test): 0.796779418321216
#         R2 score FS (Train): 0.6178176133261568
#         R2 score FS (Test): 0.636480469796866
#     Trying order: 14
#         R2 score OSA (Train): 0.8266598208909748
#         R2 score OSA (Test): 0.7941353006264986
#         R2 score FS (Train): 0.6088868620233585
#         R2 score FS (Test): 0.6294342044386821
#     Trying order: 15
#         R2 score OSA (Train): 0.8247832771832297
#         R2 score OSA (Test): 0.7875290319010954
#         R2 score FS (Train): 0.6147971254925713
#         R2 score FS (Test): 0.618188757163507
#     Trying order: 16
#         R2 score OSA (Train): 0.8624381960035231
#         R2 score OSA (Test): 0.8243559613950975
#         R2 score FS (Train): 0.15354836275105266
#         R2 score FS (Test): 0.16310812015226883
#     Trying order: 17
#         R2 score OSA (Train): 0.8545162954949921
#         R2 score OSA (Test): 0.8178416250640262
#         R2 score FS (Train): 0.5223339834303811
#         R2 score FS (Test): 0.5383377041560531
#     Trying order: 18
#         R2 score OSA (Train): 0.8108350727498903
#         R2 score OSA (Test): 0.7971424068831161
#         R2 score FS (Train): -0.127429264224157
#         R2 score FS (Test): -0.15515156959323084
#     Trying order: 19
#         R2 score OSA (Train): 0.8482502628450468
#         R2 score OSA (Test): 0.8058309419633986
#         R2 score FS (Train): 0.4655948024977654
#         R2 score FS (Test): 0.4595095636224388
#     Trying order: 20
#         R2 score OSA (Train): 0.7878376497317734
#         R2 score OSA (Test): 0.7600843839576535
#         R2 score FS (Train): 0.6384403376204237
#         R2 score FS (Test): 0.6393097067660989
#
#     Tempo de execução: 0:01:23.699994
#     Best Order: 20
#     R2 score OSA (Train): 0.7878376497317734
#     R2 score OSA (Test): 0.7600843839576535
#     R2 score FS (Train): 0.6384403376204237
#     R2 score FS (Test): 0.6393097067660989
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9434614031925405
#         R2 score OSA (Test): 0.8917278736396581
#         R2 score FS (Train): 0.6730372275333241
#         R2 score FS (Test): 0.654752708141884
#     Trying order: 3
#         R2 score OSA (Train): 0.945585232150226
#         R2 score OSA (Test): 0.8890869958252822
#         R2 score FS (Train): 0.6739872159442063
#         R2 score FS (Test): 0.6390733240872521
#     Trying order: 4
#         R2 score OSA (Train): 0.9089248266783181
#         R2 score OSA (Test): 0.867003177354031
#         R2 score FS (Train): 0.6781028898757182
#         R2 score FS (Test): 0.6625631998254262
#     Trying order: 5
#         R2 score OSA (Train): 0.9175923445673739
#         R2 score OSA (Test): 0.873902981311883
#         R2 score FS (Train): 0.7154939668139476
#         R2 score FS (Test): 0.6874161651107427
#     Trying order: 6
#         R2 score OSA (Train): 0.9229301386802301
#         R2 score OSA (Test): 0.8754117973483772
#         R2 score FS (Train): 0.7328028034635755
#         R2 score FS (Test): 0.7043101936110037
#     Trying order: 7
#         R2 score OSA (Train): 0.9114810865023365
#         R2 score OSA (Test): 0.8671233404309335
#         R2 score FS (Train): 0.7110578956949232
#         R2 score FS (Test): 0.6947846410681155
#     Trying order: 8
#         R2 score OSA (Train): 0.9530428419217762
#         R2 score OSA (Test): 0.8974231079549737
#         R2 score FS (Train): 0.7232699570914962
#         R2 score FS (Test): 0.6892345419460062
#     Trying order: 9
#         R2 score OSA (Train): 0.9556106415811901
#         R2 score OSA (Test): 0.8994218061347651
#         R2 score FS (Train): 0.726998876036371
#         R2 score FS (Test): 0.7011713898698386
#     Trying order: 10
#         R2 score OSA (Train): 0.9540523820034515
#         R2 score OSA (Test): 0.8968147709071367
#         R2 score FS (Train): 0.7289121582206495
#         R2 score FS (Test): 0.7015266501663067
#     Trying order: 11
#         R2 score OSA (Train): 0.9539774619922745
#         R2 score OSA (Test): 0.8988628989860664
#         R2 score FS (Train): 0.7254428676123446
#         R2 score FS (Test): 0.7009481764887305
#     Trying order: 12
#         R2 score OSA (Train): 0.9420736819275258
#         R2 score OSA (Test): 0.8928128312866468
#         R2 score FS (Train): 0.7064710668313343
#         R2 score FS (Test): 0.6820174292204382
#     Trying order: 13
#         R2 score OSA (Train): 0.9423130609272959
#         R2 score OSA (Test): 0.8938839678701064
#         R2 score FS (Train): 0.707218338414604
#         R2 score FS (Test): 0.68599595306747
#     Trying order: 14
#         R2 score OSA (Train): 0.9412385187647916
#         R2 score OSA (Test): 0.8938767378999012
#         R2 score FS (Train): 0.7266516800877054
#         R2 score FS (Test): 0.7084592438734321
#     Trying order: 15
#         R2 score OSA (Train): 0.9571931357410886
#         R2 score OSA (Test): 0.9022888375943493
#         R2 score FS (Train): 0.7340653221902509
#         R2 score FS (Test): 0.707812337885583
#     Trying order: 16
#         R2 score OSA (Train): 0.9444681315773846
#         R2 score OSA (Test): 0.8998170485598961
#         R2 score FS (Train): 0.7140298116403574
#         R2 score FS (Test): 0.701852311369109
#     Trying order: 17
#         R2 score OSA (Train): 0.9536882017073863
#         R2 score OSA (Test): 0.9026719896089572
#         R2 score FS (Train): 0.7130743723113951
#         R2 score FS (Test): 0.6944761683897511
#     Trying order: 18
#         R2 score OSA (Train): 0.9174889408109322
#         R2 score OSA (Test): 0.8700763300691057
#         R2 score FS (Train): 0.7362993659588633
#         R2 score FS (Test): 0.7018481611984577
#     Trying order: 19
#         R2 score OSA (Train): 0.9590505196946989
#         R2 score OSA (Test): 0.9055802220091015
#         R2 score FS (Train): 0.7098006980302547
#         R2 score FS (Test): 0.6907974241762267
#     Trying order: 20
#         R2 score OSA (Train): 0.9331207531591332
#         R2 score OSA (Test): 0.8877931632945761
#         R2 score FS (Train): 0.7375735685199536
#         R2 score FS (Test): 0.7138244097193205
#
#     Tempo de execução: 0:45:41.607564
#     Best Order: 20
#     R2 score OSA (Train): 0.9331207531591332
#     R2 score OSA (Test): 0.8877931632945761
#     R2 score FS (Train): 0.7375735685199536
#     R2 score FS (Test): 0.7138244097193205
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.973316270030258
#         R2 score OSA (Test): 0.9066913707494736
#         R2 score FS (Train): 0.7293462845758236
#         R2 score FS (Test): 0.6813396654400679
#     Trying order: 3
#         R2 score OSA (Train): 0.899685995895917
#         R2 score OSA (Test): 0.8638466702917721
#         R2 score FS (Train): 0.6087810951940147
#         R2 score FS (Test): 0.5779785502996446
#     Trying order: 4
#         R2 score OSA (Train): 0.9145435869833363
#         R2 score OSA (Test): 0.8658756369209071
#         R2 score FS (Train): 0.7224484843510178
#         R2 score FS (Test): 0.700520772085182
#     Trying order: 5
#         R2 score OSA (Train): 0.8920697915681923
#         R2 score OSA (Test): 0.8499885392993105
#         R2 score FS (Train): 0.7251773639369993
#         R2 score FS (Test): 0.694487025627585
#     Trying order: 6
#         R2 score OSA (Train): 0.9674065529060492
#         R2 score OSA (Test): 0.9032313813449915
#         R2 score FS (Train): 0.7277065622699677
#         R2 score FS (Test): 0.6982409530152662
#     Trying order: 7
#         R2 score OSA (Train): 0.8941351153944208
#         R2 score OSA (Test): 0.8468355262525709
#         R2 score FS (Train): 0.7320216650316047
#         R2 score FS (Test): 0.6886840830942167
#     Trying order: 8
#         R2 score OSA (Train): 0.9250160800569788
#         R2 score OSA (Test): 0.879267872517543
#         R2 score FS (Train): 0.740067739929466
#         R2 score FS (Test): 0.7144872406099783
#     Trying order: 9
#         R2 score OSA (Train): 0.9199194643626345
#         R2 score OSA (Test): 0.878693464025127
#         R2 score FS (Train): 0.720541677072376
#         R2 score FS (Test): 0.7031402326152973
#     Trying order: 10
#         R2 score OSA (Train): 0.902905080375661
#         R2 score OSA (Test): 0.8482790600514165
#         R2 score FS (Train): 0.7568848102014798
#         R2 score FS (Test): 0.7188747791658054
#     Trying order: 11
#         R2 score OSA (Train): 0.9094197770520559
#         R2 score OSA (Test): 0.8624430818637439
#         R2 score FS (Train): 0.7097424197697602
#         R2 score FS (Test): 0.6705149358452027
#     Trying order: 12
#         R2 score OSA (Train): 0.9284884944079943
#         R2 score OSA (Test): 0.8809607946986351
#         R2 score FS (Train): 0.7552988217785712
#         R2 score FS (Test): 0.7297301555010539
#     Trying order: 13
#         R2 score OSA (Train): 0.9079788520257638
#         R2 score OSA (Test): 0.8625254656630794
#         R2 score FS (Train): 0.7548518104685094
#         R2 score FS (Test): 0.7318448131197915
#     Trying order: 14
#         R2 score OSA (Train): 0.9288364532797855
#         R2 score OSA (Test): 0.8806087961914355
#         R2 score FS (Train): 0.7410442139144926
#         R2 score FS (Test): 0.7239447385717448
#     Trying order: 15
#         R2 score OSA (Train): 0.9309600593546477
#         R2 score OSA (Test): 0.8771265442893125
#         R2 score FS (Train): 0.7334194916007866
#         R2 score FS (Test): 0.7124235577744831
#     Trying order: 16
#         R2 score OSA (Train): 0.9250371126073423
#         R2 score OSA (Test): 0.878581238632992
#         R2 score FS (Train): 0.7061093730931978
#         R2 score FS (Test): 0.6947382847820319
#     Trying order: 17
#         R2 score OSA (Train): 0.9306447467700091
#         R2 score OSA (Test): 0.8795570550424991
#         R2 score FS (Train): 0.7285799257279157
#         R2 score FS (Test): 0.7111344466060641
#     Trying order: 18
#         R2 score OSA (Train): 0.9275537555689134
#         R2 score OSA (Test): 0.8832881318856327
#         R2 score FS (Train): 0.6701725284625346
#         R2 score FS (Test): 0.6621139980028422
#     Trying order: 19
#         R2 score OSA (Train): 0.9749303029204777
#         R2 score OSA (Test): 0.9137118872921574
#         R2 score FS (Train): 0.7639248462090974
#         R2 score FS (Test): 0.7565720834626386
#     Trying order: 20
#         R2 score OSA (Train): 0.9266249227404597
#         R2 score OSA (Test): 0.8816009643105026
#         R2 score FS (Train): 0.7358049070994392
#         R2 score FS (Test): 0.7238456671196035
#
#     Tempo de execução: 1:06:08.787800
#     Best Order: 19
#     R2 score OSA (Train): 0.9749303029204777
#     R2 score OSA (Test): 0.9137118872921574
#     R2 score FS (Train): 0.7639248462090974
#     R2 score FS (Test): 0.7565720834626386
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.9044470712401839
#         R2 score OSA (Test): 0.8667825446502417
#         R2 score FS (Train): 0.7095833718699845
#         R2 score FS (Test): 0.6875770400782201
#     Trying order: 3
#         R2 score OSA (Train): 0.95086020600555
#         R2 score OSA (Test): 0.890196584597609
#         R2 score FS (Train): 0.7361378328427016
#         R2 score FS (Test): 0.6912193683661482
#     Trying order: 4
#         R2 score OSA (Train): 0.918036700394626
#         R2 score OSA (Test): 0.8728745189510214
#         R2 score FS (Train): 0.7093280892214722
#         R2 score FS (Test): 0.6673972525640259
#     Trying order: 5
#         R2 score OSA (Train): 0.9366718404714287
#         R2 score OSA (Test): 0.8839930292166642
#         R2 score FS (Train): 0.7414536520704798
#         R2 score FS (Test): 0.7016264064179092
#     Trying order: 6
#         R2 score OSA (Train): 0.9665052251550116
#         R2 score OSA (Test): 0.8980903812287042
#         R2 score FS (Train): 0.7373427456276951
#         R2 score FS (Test): 0.6970216690717406
#     Trying order: 7
#         R2 score OSA (Train): 0.909181746283252
#         R2 score OSA (Test): 0.8617749873376828
#         R2 score FS (Train): 0.7053466638031896
#         R2 score FS (Test): 0.6631525942530295
#     Trying order: 8
#         R2 score OSA (Train): 0.9473458922274043
#         R2 score OSA (Test): 0.8863515516289097
#         R2 score FS (Train): 0.7589166451627589
#         R2 score FS (Test): 0.714797307494165
#     Trying order: 9
#         R2 score OSA (Train): 0.9735043246879933
#         R2 score OSA (Test): 0.9044824851822437
#         R2 score FS (Train): 0.7670788809354888
#         R2 score FS (Test): 0.7221765849098554
#     Trying order: 10
#         R2 score OSA (Train): 0.9503618997490729
#         R2 score OSA (Test): 0.8873193623583953
#         R2 score FS (Train): 0.7523816887911694
#         R2 score FS (Test): 0.7128444719874758
#     Trying order: 11
#         R2 score OSA (Train): 0.9747420578807322
#         R2 score OSA (Test): 0.9095726462187913
#         R2 score FS (Train): 0.7574858161088031
#         R2 score FS (Test): 0.7233721723646123
#     Trying order: 12
#         R2 score OSA (Train): 0.9756656104830879
#         R2 score OSA (Test): 0.9078300824622857
#         R2 score FS (Train): 0.7661349676801641
#         R2 score FS (Test): 0.7299738870878205
#     Trying order: 13
#         R2 score OSA (Train): 0.9550440286797808
#         R2 score OSA (Test): 0.8929533154786372
#         R2 score FS (Train): 0.7524134237837992
#         R2 score FS (Test): 0.721279203084322
#     Trying order: 14
#         R2 score OSA (Train): 0.9777884250298211
#         R2 score OSA (Test): 0.9055453864467616
#         R2 score FS (Train): 0.7608343325985303
#         R2 score FS (Test): 0.7329038282426216
#     Trying order: 15
#         R2 score OSA (Train): 0.97801693171537
#         R2 score OSA (Test): 0.9079692414622876
#         R2 score FS (Train): 0.7524208281620267
#         R2 score FS (Test): 0.7241024442647312
#     Trying order: 16
#         R2 score OSA (Train): 0.9197595906672476
#         R2 score OSA (Test): 0.8722268322865082
#         R2 score FS (Train): 0.675137742393044
#         R2 score FS (Test): 0.6553347789530994
#     Trying order: 17
#         R2 score OSA (Train): 0.9155688678386606
#         R2 score OSA (Test): 0.8598626362638353
#         R2 score FS (Train): 0.6833463025339671
#         R2 score FS (Test): 0.6509307336945134
#     Trying order: 18
#         R2 score OSA (Train): 0.9136015704810064
#         R2 score OSA (Test): 0.8608914487448835
#         R2 score FS (Train): 0.7069251351002155
#         R2 score FS (Test): 0.6801669840664234
#     Trying order: 19
#         R2 score OSA (Train): 0.9210052245237784
#         R2 score OSA (Test): 0.8705842637853983
#         R2 score FS (Train): 0.6783168273361655
#         R2 score FS (Test): 0.6592374802163873
#     Trying order: 20
#         R2 score OSA (Train): 0.9247822342245899
#         R2 score OSA (Test): 0.873289324794777
#         R2 score FS (Train): 0.7000026647773667
#         R2 score FS (Test): 0.6733670141531545
#
#     Tempo de execução: 0:52:13.794463
#     Best Order: 9
#     R2 score OSA (Train): 0.9735043246879933
#     R2 score OSA (Test): 0.9044824851822437
#     R2 score FS (Train): 0.7670788809354888
#     R2 score FS (Test): 0.7221765849098554
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.8369101298563482
#         R2 score OSA (Test): 0.8127488216775582
#         R2 score FS (Train): 0.6668879378490431
#         R2 score FS (Test): 0.6623758711361032
#     Trying order: 3
#         R2 score OSA (Train): 0.824925047961071
#         R2 score OSA (Test): 0.8149170373809781
#         R2 score FS (Train): 0.6430570080957516
#         R2 score FS (Test): 0.6494558396351584
#     Trying order: 4
#         R2 score OSA (Train): 0.8308115911879816
#         R2 score OSA (Test): 0.8132636673647973
#         R2 score FS (Train): 0.645215773112759
#         R2 score FS (Test): 0.6408235808335994
#     Trying order: 5
#         R2 score OSA (Train): 0.8506072658498758
#         R2 score OSA (Test): 0.8186325918379469
#         R2 score FS (Train): 0.6910592615349649
#         R2 score FS (Test): 0.6891736454995661
#     Trying order: 6
#         R2 score OSA (Train): 0.8976603409240708
#         R2 score OSA (Test): 0.8518455990626781
#         R2 score FS (Train): 0.7228696980408654
#         R2 score FS (Test): 0.6884642402726241
#     Trying order: 7
#         R2 score OSA (Train): 0.8662351041161861
#         R2 score OSA (Test): 0.8399047952477852
#         R2 score FS (Train): 0.6640454473963341
#         R2 score FS (Test): 0.6617143774572503
#     Trying order: 8
#         R2 score OSA (Train): 0.8708510368846296
#         R2 score OSA (Test): 0.8285573351004548
#         R2 score FS (Train): 0.5785943701331266
#         R2 score FS (Test): 0.6090668921457177
#     Trying order: 9
#         R2 score OSA (Train): 0.8857893227601541
#         R2 score OSA (Test): 0.8378730835982363
#         R2 score FS (Train): 0.7057256365702248
#         R2 score FS (Test): 0.7039730879911449
#     Trying order: 10
#         R2 score OSA (Train): 0.8635481769849852
#         R2 score OSA (Test): 0.8255576759679654
#         R2 score FS (Train): 0.569942114949915
#         R2 score FS (Test): 0.6038523783157197
#     Trying order: 11
#         R2 score OSA (Train): 0.83848022798129
#         R2 score OSA (Test): 0.8119668288435103
#         R2 score FS (Train): 0.654230437434733
#         R2 score FS (Test): 0.6686135092780896
#     Trying order: 12
#         R2 score OSA (Train): 0.9061400534456475
#         R2 score OSA (Test): 0.858302017740099
#         R2 score FS (Train): 0.6920113649015341
#         R2 score FS (Test): 0.6917779185043702
#     Trying order: 13
#         R2 score OSA (Train): 0.8915596160317821
#         R2 score OSA (Test): 0.8467711878789412
#         R2 score FS (Train): 0.7224129649606075
#         R2 score FS (Test): 0.7164182319356187
#     Trying order: 14
#         R2 score OSA (Train): 0.8792132395128799
#         R2 score OSA (Test): 0.8257667651899979
#         R2 score FS (Train): 0.6882646250660553
#         R2 score FS (Test): 0.6927983545670455
#     Trying order: 15
#         R2 score OSA (Train): 0.8896494918974038
#         R2 score OSA (Test): 0.8355219088580834
#         R2 score FS (Train): 0.6850264771910988
#         R2 score FS (Test): 0.6872821047553046
#     Trying order: 16
#         R2 score OSA (Train): 0.89554351246207
#         R2 score OSA (Test): 0.8528529627423702
#         R2 score FS (Train): 0.6744140690552702
#         R2 score FS (Test): 0.6728493482496154
#     Trying order: 17
#         R2 score OSA (Train): 0.8143940612625584
#         R2 score OSA (Test): 0.7997971070648833
#         R2 score FS (Train): 0.6412714978033037
#         R2 score FS (Test): 0.6595597896350005
#     Trying order: 18
#         R2 score OSA (Train): 0.8463988912586792
#         R2 score OSA (Test): 0.8114054210590657
#         R2 score FS (Train): 0.6993567344339934
#         R2 score FS (Test): 0.707401550684207
#     Trying order: 19
#         R2 score OSA (Train): 0.7995179670642297
#         R2 score OSA (Test): 0.7829288255977369
#         R2 score FS (Train): 0.6407466934401223
#         R2 score FS (Test): 0.658978264935455
#     Trying order: 20
#         R2 score OSA (Train): 0.8525203624293962
#         R2 score OSA (Test): 0.8143035776284226
#         R2 score FS (Train): 0.6780195920225274
#         R2 score FS (Test): 0.6868203372785758
#
#     Tempo de execução: 3:35:42.963946
#     Best Order: 6
#     R2 score OSA (Train): 0.8976603409240708
#     R2 score OSA (Test): 0.8518455990626781
#     R2 score FS (Train): 0.7228696980408654
#     R2 score FS (Test): 0.6884642402726241

# %%
pd.DataFrame(results)
# Out:
#                MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS  \
# 0              ARMAX     11      0.758957     0.760379    -0.088821
# 1             NARMAX      2      0.780825     0.772464     0.616217
# 2             LinReg      4      0.803836     0.795057     0.584551
# 3            PolyReg      5      0.821202     0.810080     0.655108
# 4                SVM     12      0.816499     0.799001     0.623149
# 5                KNN     20      1.000000     0.892558     0.721787
# 6       DecisionTree     20      0.787838     0.760084     0.638440
# 7       RandomForest     20      0.933121     0.887793     0.737574
# 8   GradientBoosting     19      0.974930     0.913712     0.763925
# 9         ExtraTrees      9      0.973504     0.904482     0.767079
# 10               MLP      6      0.897660     0.851846     0.722870
#
#     R2 TEST FS                                          MODEL OBJ  \
# 0    -0.087812  <sysidentpy.model_structure_selection.forward_...
# 1     0.601519  <sysidentpy.model_structure_selection.forward_...
# 2     0.592395  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 3     0.662723  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 4     0.634136  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 5     0.675835  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 6     0.639310  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 7     0.713824  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 8     0.756572  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 9     0.722177  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 10    0.688464  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
#
#                                                  PARS
# 0    [[1001], [2001], [1010], [1002], [1003], [1004]]
# 1   [[2002, 2001], [6002, 1001], [3002, 0], [6001,...
# 2                                  {'positive': True}
# 3                             {'Reg__positive': True}
# 4   {'C': 11.272575863403866, 'degree': 5, 'gamma'...
# 5           {'n_neighbors': 4, 'weights': 'distance'}
# 6   {'max_depth': 10, 'max_features': 0.1998418721...
# 7   {'max_depth': 11, 'max_features': 0.2391315093...
# 8   {'criterion': 'friedman_mse', 'learning_rate':...
# 9   {'criterion': 'squared_error', 'max_depth': 14...
# 10  {'activation': 'relu', 'alpha': 0.001471486110...

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#      MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS   R2 TEST FS  \
# 0    ARMAX      2      0.764163     0.758294  -202.334814  -195.360214
# 1    ARMAX      3      0.743791     0.748160  -745.303495  -696.163574
# 2    ARMAX      4      0.747202     0.756769  -532.554143  -494.972925
# 3    ARMAX      5      0.736458     0.754493 -2738.524333 -2709.145318
# 4    ARMAX      6      0.760238     0.768703   -19.406413   -20.040432
# ..     ...    ...           ...          ...          ...          ...
# 204    MLP     16      0.895544     0.852853     0.674414     0.672849
# 205    MLP     17      0.814394     0.799797     0.641271     0.659560
# 206    MLP     18      0.846399     0.811405     0.699357     0.707402
# 207    MLP     19      0.799518     0.782929     0.640747     0.658978
# 208    MLP     20      0.852520     0.814304     0.678020     0.686820
#
#                                              MODEL OBJ
# 0    <sysidentpy.model_structure_selection.forward_...
# 1    <sysidentpy.model_structure_selection.forward_...
# 2    <sysidentpy.model_structure_selection.forward_...
# 3    <sysidentpy.model_structure_selection.forward_...
# 4    <sysidentpy.model_structure_selection.forward_...
# ..                                                 ...
# 204  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 205  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 206  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 207  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 208  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
#
# [209 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/Semestre 02/SYSID/SYSID_Trabalho/Volve-Dataset/outputs/MISO.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# {'activation': 'relu', 'alpha': 0.0014714861101156717, 'batch_size': 128, 'early_stopping': False, 'hidden_layer_sizes': (20, 40, 20, 40), 'max_iter': 10000, 'solver': 'adam', 'tol': 5.565552416696972e-06}
